# %% [markdown]
# <figure>
#   <IMG src="figures/logo-esi-sba.png" WIDTH=300 height="100" ALIGN="right">
# </figure>
#
# # Practical Trainining Series on Modeling And Simulation
# *By Dr. Belkacem KHALDI (b.khaldi@esi-sba.dz)*

# %% [markdown]
# ## Notebook 7: Modeling and Simulating Discrete-Event Systems
# <figure>
#   <IMG src="figures/ch7-des-fig1.png" WIDTH=400 height="400" ALIGN="right">
# </figure>
#
# In this Notebook you learn how to model and simulate Discerte-Event systems using simpy python library.
# Discrete-Event Systems are a type of systems that are driven by discret-events. The state of such systems is changed whenever an event occures. The occurence of an event is mostely stochastic in time and therefore the  inter-arival events time is discret.
#
# ### simpy
# SimPy is a discrete-event simulation library. The behavior of active components (like vehicles, customers or messages) is modeled with processes. All processes live in an environment. They interact with the environment and with each other via events.
#
#  First of all we will need the simpy python library to simulate such systens

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install simpy
import simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.0.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.0.1
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\habs\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Our First Process
# Let's simulate our first example which will be about a Customer visiting a Bank. We assume that the Bank is always full of customers and when the visitor arrives, he will stay just 10 minites there and then leave the Bank without even being served. We assume also that our customer will frequently visit the Bank each 30 minutes and he will alternately arrive and leave for a while. When he arrives (or leaves) the Bank, we will print and save both the current sate and simulation time. So, the customer switches between the states arriving and departure.

# %%
import simpy
import pandas as pd
import matplotlib.pyplot as plt

arriving_duration = 10
departure_duration = 30
simulation_time=120
#A list for saving purposes
events=[]
#Define a customer process that requires a reference to an simpy.Environment (env) in order to create new events
def Customer(env,name):
    # To be runned in infinite loop. 
    while True:
        #Announcing the arriving state by printing a message and the current simulation time
        print('Mr. %s Arrives at the Bank at %d' % (name, env.now))
        #save the actual time and state 
        events.append([env.now,'arriving'])
        
        
        #Create a Timeout event and wait for the event to occur. in a given amount of time
        yield env.timeout(arriving_duration)
        
        
        #Announcing the departure state by printing a message and the current simulation time
        print('Mr. %s leaves the Bank at %d' % (name, env.now))
        #save the actual time and state 
        events.append([env.now,'departure'])
        
        #Create a Timeout event and wait for the event to occur. in a given amount of time
        yield env.timeout(departure_duration)
        
        
# create an instance of Simpy Environment. 
env = simpy.Environment()
#Passing env into our customer process function. 
#Started a process and added to the environment

env.process(Customer(env,'KHALDI'))
#start the simulation by calling run() and passing an end time to it.
env.run(until=simulation_time)

#Create a dataframe from list events and plot
df=pd.DataFrame(events, columns=['time','event'])
plt.step(df['time'],df['event'])
plt.xlabel('Time')
plt.ylabel('State')
# Out:
# Mr. KHALDI Arrives at the Bank at 0
# Mr. KHALDI leaves the Bank at 10
# Mr. KHALDI Arrives at the Bank at 40
# Mr. KHALDI leaves the Bank at 50
# Mr. KHALDI Arrives at the Bank at 80
# Mr. KHALDI leaves the Bank at 90
# Text(0, 0.5, 'State')

# %% [markdown]
# ### Challenge 1:
# Recretae the above scenario by assuming now that the arriving and departure duration are stochastic (random).
# #### Hint
# Use randint from the random import library

# %%
#your code here
import simpy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

arriving_duration = np.random.randint(0,20)
departure_duration = np.random.randint(0,20)
simulation_time=120
#A list for saving purposes
events=[]
#Define a customer process that requires a reference to an simpy.Environment (env) in order to create new events
def Customer(env,name):
    # To be runned in infinite loop. 
    while True:
        #Announcing the arriving state by printing a message and the current simulation time
        print('Mr. %s Arrives at the Bank at %d' % (name, env.now))
        #save the actual time and state 
        events.append([env.now,'arriving'])
        
        #Create a Timeout event and wait for the event to occur. in a given amount of time
        yield env.timeout(arriving_duration)
        
        #Announcing the departure state by printing a message and the current simulation time
        print('Mr. %s leaves the Bank at %d' % (name, env.now))
        #save the actual time and state 
        events.append([env.now,'departure'])
        
        #Create a Timeout event and wait for the event to occur. in a given amount of time
        yield env.timeout(departure_duration)
        
        
# create an instance of Simpy Environment. 
env = simpy.Environment()
#Passing env into our customer process function. 
#Started a process and added to the environment

env.process(Customer(env,'habs'))
#start the simulation by calling run() and passing an end time to it.
env.run(until=simulation_time)

#Create a dataframe from list events and plot
df=pd.DataFrame(events, columns=['time','event'])
plt.step(df['time'],df['event'])
plt.xlabel('Time')
plt.ylabel('State')
plt.show()
# Out:
# Mr. habs Arrives at the Bank at 0
# Mr. habs leaves the Bank at 8
# Mr. habs Arrives at the Bank at 21
# Mr. habs leaves the Bank at 29
# Mr. habs Arrives at the Bank at 42
# Mr. habs leaves the Bank at 50
# Mr. habs Arrives at the Bank at 63
# Mr. habs leaves the Bank at 71
# Mr. habs Arrives at the Bank at 84
# Mr. habs leaves the Bank at 92
# Mr. habs Arrives at the Bank at 105
# Mr. habs leaves the Bank at 113

# %% [markdown]
# ## Our Second Process
# Let's assume now that our Customer decides to wait for his service at the Bank. We assume that the Bank has one desk that serves all the cutomers with a Queue type notation (D/D/1). The arriver of a customer is set to be each 7 minutes and the time taken to serve a customer is set to be 5 minutes.
# ### Hint:
# This system is of Queue Type Notation D/D/1 because:

# %%
"""
Bank example.

Covers:

- Waiting for other processes
- Resources: Resource

Scenario:
  A Bank has a limited number of service desks and defines
  a service processes that takes some (random) time.

  Customer processes arrive at the Bank at a random time. If one Service
  desk is available, they start serving the customer and wait for it
  to finish. If not, they wait until they  use one.

"""
import numpy.random as rnd
import simpy
import pandas as pd


RANDOM_SEED = 42
NUM_DESKS = 1      # Number of service desks in the Bank
SERVICETIME = 5    # Minutes it takes to serve a customer
T_INTER = 10        # Create a customer every ~10 minutes
SIM_TIME = 45      # Simulation time in minutes

events=[]

class Bank(object):
    """A Bank has a limited number of service desks (``NUM_DESKS``) to
    serve customers in parallel.

    Customers have to request one of the service desks. When they got one, they
    be served and wait for the agent to finish their request which 
    takes ``SERVICETIME`` minutes).

    """
    def __init__(self, env, num_desks, service_time):
        self.env = env
        self.desk = simpy.Resource(env, num_desks)
        self.serviceTime = service_time

    def service(self, customer):
        """The service processes. It takes a ``customer`` processes and tries
        to serve it."""
       
        
        yield self.env.timeout(SERVICETIME)
        print("The Bank agent is serving %d%% of %s's service request." %
              (rnd.randint(75, 99), customer))
        events.append([env.now,customer,'in service'])

def customer(env, name, bk):
    """
    The customer process (each customer has a ``name``) arrives at the Bank
    (``bk``) and requests a service desk.

    It then  waits for the agent to finialize his request and
    leaves to never come back ...

    """
    print('%s arrives at the Bank at %.2f.' % (name, env.now))
    events.append([env.now,name,'arriving'])
    with bk.desk.request() as request:
        # Waiting for the customer's turn to be served
        yield request
        events.append([env.now,name,'waiting'])
        print('%s is being served %.2f.' % (name, env.now))
        
        yield env.process(bk.service(name))
        events.append([env.now, name,'departure'])
        print('%s leaves the Bank at %.2f.' % (name, env.now))


def setup(env, num_desks, service_time, t_inter):
    """
    Create a Bank, a number of initial customers and keep creating customers
    approx. every ``t_inter`` minutes.
    """
    # Create the Bank
    bk = Bank(env, num_desks, service_time)

    # We assume that at the beginning the 4 customers are already in queue
    for i in range(4):
        env.process(customer(env, 'Customer %d' % i, bk))

    # Create more customers while the simulation is running
    #i=0
    while True:
        yield env.timeout(T_INTER)
        i += 1
        env.process(customer(env, 'Customer %d' % i, bk))


# Setup and start the simulation
print('Bank')


# Create an environment and start the setup process
env = simpy.Environment()
env.process(setup(env, NUM_DESKS, SERVICETIME, T_INTER))

# Execute!
env.run(until=SIM_TIME)
# Out:
# Bank
# Customer 0 arrives at the Bank at 0.00.
# Customer 1 arrives at the Bank at 0.00.
# Customer 2 arrives at the Bank at 0.00.
# Customer 3 arrives at the Bank at 0.00.
# Customer 0 is being served 0.00.
# The Bank agent is serving 89% of Customer 0's service request.
# Customer 0 leaves the Bank at 5.00.
# Customer 1 is being served 5.00.
# Customer 4 arrives at the Bank at 10.00.
# The Bank agent is serving 76% of Customer 1's service request.
# Customer 1 leaves the Bank at 10.00.
# Customer 2 is being served 10.00.
# The Bank agent is serving 86% of Customer 2's service request.
# Customer 2 leaves the Bank at 15.00.
# Customer 3 is being served 15.00.
# Customer 5 arrives at the Bank at 20.00.
# The Bank agent is serving 78% of Customer 3's service request.
# Customer 3 leaves the Bank at 20.00.
# Customer 4 is being served 20.00.
# The Bank agent is serving 80% of Customer 4's service request.
# Customer 4 leaves the Bank at 25.00.
# Customer 5 is being served 25.00.
# Customer 6 arrives at the Bank at 30.00.
# The Bank agent is serving 96% of Customer 5's service request.
# Customer 5 leaves the Bank at 30.00.
# Customer 6 is being served 30.00.
# The Bank agent is serving 84% of Customer 6's service request.
# Customer 6 leaves the Bank at 35.00.
# Customer 7 arrives at the Bank at 40.00.
# Customer 7 is being served 40.00.

# %%
import matplotlib.pyplot as plt
df=pd.DataFrame(events, columns=['time','name','event'])

fig, axs = plt.subplots(len(df['name'].drop_duplicates()),1,figsize=(15,10))
for ax,c in zip(axs.flatten(),df['name'].drop_duplicates()):
    df_c=df.loc[df['name'] == c]
    
    ax.step(df_c['time'],df_c['event'], label=c)
    ax.set_xlabel('Time')
    ax.set_ylabel('State')  
    ax.set_xlim(0, 45)
    ax.legend()

#performance
print(df)
df_w=df.loc[df['event'] == 'waiting']
print('average waiting time: %.2f minutes.' % df_w.mean())
# Out:
#     time        name       event
# 0      0  Customer 0    arriving
# 1      0  Customer 1    arriving
# 2      0  Customer 2    arriving
# 3      0  Customer 3    arriving
# 4      0  Customer 0     waiting
# 5      5  Customer 0  in service
# 6      5  Customer 0   departure
# 7      5  Customer 1     waiting
# 8     10  Customer 4    arriving
# 9     10  Customer 1  in service
# 10    10  Customer 1   departure
# 11    10  Customer 2     waiting
# 12    15  Customer 2  in service
# 13    15  Customer 2   departure
# 14    15  Customer 3     waiting
# 15    20  Customer 5    arriving
# 16    20  Customer 3  in service
# 17    20  Customer 3   departure
# 18    20  Customer 4     waiting
# 19    25  Customer 4  in service
# 20    25  Customer 4   departure
# 21    25  Customer 5     waiting
# 22    30  Customer 6    arriving
# 23    30  Customer 5  in service
# 24    30  Customer 5   departure
# 25    30  Customer 6     waiting
# 26    35  Customer 6  in service
# 27    35  Customer 6   departure
# 28    40  Customer 7    arriving
# 29    40  Customer 7     waiting
# average waiting time: 18.12 minutes.
# C:\Users\habs\AppData\Local\Temp\ipykernel_14780\4090916541.py:17: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('average waiting time: %.2f minutes.' % df_w.mean())

# %% [markdown]
# ### Challenge 2: (D/D/n)
#
# Now assume that the Bank has more than one service desks. By modifying the code above, model and simulate a Bank queueing system with n=3 service desks.

# %%
#your code here
"""
Bank example.

Covers:

- Waiting for other processes
- Resources: Resource

Scenario:
  A Bank has a limited number of service desks and defines
  a service processes that takes some (random) time.

  Customer processes arrive at the Bank at a random time. If one Service
  desk is available, they start serving the customer and wait for it
  to finish. If not, they wait until they  use one.

"""
import numpy.random as rnd
import simpy
import pandas as pd
import matplotlib.pyplot as plt


RANDOM_SEED = 42
NUM_DESKS =    3   # Number of service desks in the Bank
SERVICETIME =  5   # Minutes it takes to serve a customer
T_INTER =     10   # Create a customer every ~10 minutes
SIM_TIME =    45   # Simulation time in minutes

events=[]

class Bank(object):
    """A Bank has a limited number of service desks (``NUM_DESKS``) to
    serve customers in parallel.

    Customers have to request one of the service desks. When they got one, they
    be served and wait for the agent to finish their request which 
    takes ``SERVICETIME`` minutes).

    """
    def __init__(self, env, num_desks, service_time):
        self.env = env
        self.desk = simpy.Resource(env, num_desks)
        self.serviceTime = service_time

    def service(self, customer):
        """The service processes. It takes a ``customer`` processes and tries
        to serve it."""
        #SERVICETIME=rnd.exponential(scale=3)
        
        yield self.env.timeout(SERVICETIME)
        print("The Bank agent is serving %d%% of %s's service request." %
              (rnd.randint(75, 99), customer))
        events.append([env.now,customer,'in service'])

def customer(env, name, bk):
    """The customer process (each customer has a ``name``) arrives at the Bank
    (``bk``) and requests a service desk.

    It then  waits for the agent to finialize his request and
    leaves to never come back ...

    """
    print('%s arrives at the Bank at %.2f.' % (name, env.now))
    events.append([env.now,name,'arriving'])
    with bk.desk.request() as request:
        #waiting for the customer's turn to be served
        yield request
        events.append([env.now,name,'waiting'])
        print('%s is being served %.2f.' % (name, env.now))
        
        yield env.process(bk.service(name))
        events.append([env.now, name,'departure'])
        print('%s leaves the Bank at %.2f.' % (name, env.now))


def setup(env, num_desks, service_time, t_inter):
    """Create a Bank, a number of initial customers and keep creating customers
    approx. every ``t_inter`` minutes."""
    # Create the Bank
    bk = Bank(env, num_desks, service_time)

    #we assume that at the beginning the 4 customers are already in queue
    for i in range(4):
        env.process(customer(env, 'Customer %d' % i, bk))

    # Create more customers while the simulation is running
    #i=0
    while True:
        yield env.timeout(T_INTER)
        i += 1
        env.process(customer(env, 'Customer %d' % i, bk))


# Setup and start the simulation
print('Bank')


# Create an environment and start the setup process
env = simpy.Environment()
env.process(setup(env, NUM_DESKS, SERVICETIME, T_INTER))

# Execute!
env.run(until=SIM_TIME)

df=pd.DataFrame(events, columns=['time','name','event'])

fig, axs = plt.subplots(len(df['name'].drop_duplicates()),1,figsize=(15,10))
for ax,c in zip(axs.flatten(),df['name'].drop_duplicates()):
    df_c=df.loc[df['name'] == c]
    
    ax.step(df_c['time'],df_c['event'], label=c)
    ax.set_xlabel('Time')
    ax.set_ylabel('State')  
    ax.set_xlim(0, 45)
    ax.legend()

#performance
print(df)
df_w=df.loc[df['event'] == 'waiting']
print('average waiting time: %.2f minutes.' % df_w.mean())

plt.show()
# Out:
# Bank
# Customer 0 arrives at the Bank at 0.00.
# Customer 1 arrives at the Bank at 0.00.
# Customer 2 arrives at the Bank at 0.00.
# Customer 3 arrives at the Bank at 0.00.
# Customer 0 is being served 0.00.
# Customer 1 is being served 0.00.
# Customer 2 is being served 0.00.
# The Bank agent is serving 82% of Customer 0's service request.
# The Bank agent is serving 82% of Customer 1's service request.
# The Bank agent is serving 89% of Customer 2's service request.
# Customer 0 leaves the Bank at 5.00.
# Customer 1 leaves the Bank at 5.00.
# Customer 2 leaves the Bank at 5.00.
# Customer 3 is being served 5.00.
# Customer 4 arrives at the Bank at 10.00.
# The Bank agent is serving 87% of Customer 3's service request.
# Customer 4 is being served 10.00.
# Customer 3 leaves the Bank at 10.00.
# The Bank agent is serving 93% of Customer 4's service request.
# Customer 4 leaves the Bank at 15.00.
# Customer 5 arrives at the Bank at 20.00.
# Customer 5 is being served 20.00.
# The Bank agent is serving 96% of Customer 5's service request.
# Customer 5 leaves the Bank at 25.00.
# Customer 6 arrives at the Bank at 30.00.
# Customer 6 is being served 30.00.
# The Bank agent is serving 80% of Customer 6's service request.
# Customer 6 leaves the Bank at 35.00.
# Customer 7 arrives at the Bank at 40.00.
# Customer 7 is being served 40.00.
#     time        name       event
# 0      0  Customer 0    arriving
# 1      0  Customer 1    arriving
# 2      0  Customer 2    arriving
# 3      0  Customer 3    arriving
# 4      0  Customer 0     waiting
# 5      0  Customer 1     waiting
# 6      0  Customer 2     waiting
# 7      5  Customer 0  in service
# 8      5  Customer 1  in service
# 9      5  Customer 2  in service
# 10     5  Customer 0   departure
# 11     5  Customer 1   departure
# 12     5  Customer 2   departure
# 13     5  Customer 3     waiting
# 14    10  Customer 4    arriving
# 15    10  Customer 3  in service
# 16    10  Customer 4     waiting
# 17    10  Customer 3   departure
# 18    15  Customer 4  in service
# 19    15  Customer 4   departure
# 20    20  Customer 5    arriving
# 21    20  Customer 5     waiting
# 22    25  Customer 5  in service
# 23    25  Customer 5   departure
# 24    30  Customer 6    arriving
# 25    30  Customer 6     waiting
# 26    35  Customer 6  in service
# 27    35  Customer 6   departure
# 28    40  Customer 7    arriving
# 29    40  Customer 7     waiting
# average waiting time: 13.12 minutes.
# C:\Users\habs\AppData\Local\Temp\ipykernel_14780\2927822789.py:122: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('average waiting time: %.2f minutes.' % df_w.mean())

# %% [markdown]
# ### Challenge 3: (M/M/1 and M/M/n)
# Now modify your code to model/simulate a Bank queueing system with the following queue type notation:
# <ol type="I">
#   <li>M/M/1 with arriving rate $\lambda=10$ and departure rate $\mu=5$</li>
#   <li>M/M/3</li>
# </ol>
# Note that M/M/1 means both arriver and departure are Markovian (Exponential)
#
# #### Hint:
# The arriver and departure time is modeled using an exponential probability distribution. you can use either:
# <ol type="I">
#   <li>numpy.random.exponential(scale=rate)</li>
#   <li>random.expovariate(1/rate)</li>
# </ol>

# %%
# Your code for M/M/1
import numpy.random as rnd
import simpy

RANDOM_SEED = 39
NUM_DESKS = 1      # Number of service desks in the Bank
ARRIVAL_RATE = 10  # Arrival rate of customers (per minute)
DEPARTURE_RATE = 5 # Departure rate of customers (per minute)
SIM_TIME = 10       # Simulation time in minutes

events = []

class Bank(object):
    """A Bank has a limited number of service desks (``NUM_DESKS``) to
    serve customers in parallel.

    Customers have to request one of the service desks. When they get one, they
    are served and wait for the agent to finish their request which 
    takes a random service time.

    """
    def __init__(self, env, num_desks, departure_rate):
        self.env = env
        self.desk = simpy.Resource(env, num_desks)
        self.departureRate = departure_rate

    def service(self, customer):
        """The service process. It takes a ``customer`` process and tries
        to serve it."""
        service_time = rnd.exponential(scale = 1 / self.departureRate)
        yield self.env.timeout(service_time)
        print("The Bank agent is serving %d%% of %s's service request." %
              (rnd.randint(75, 99), customer))
        events.append([env.now, customer, 'in service'])

def customer(env, name, bk):
    """
    The customer process (each customer has a ``name``) arrives at the Bank
    (``bk``) and requests a service desk.

    It then waits for the agent to finalize the request and
    leaves to never come back ...

    """
    print('%s arrives at the Bank at %.2f.' % (name, env.now))
    events.append([env.now, name, 'arriving'])
    with bk.desk.request() as request:
        # Waiting for the customer's turn to be served
        yield request
        events.append([env.now, name, 'waiting'])
        print('%s is being served at %.2f.' % (name, env.now))
        yield env.process(bk.service(name))
        events.append([env.now, name, 'departure'])
        print('%s leaves the Bank at %.2f.' % (name, env.now))

def setup(env, num_desks, arrival_rate, departure_rate):
    """
    Create a Bank, a number of initial customers, and keep creating customers
    with exponential inter-arrival times.
    """
    # Create the Bank
    bk = Bank(env, num_desks, departure_rate)

    # We assume that at the beginning the 4 customers are already in queue
    for i in range(4):
        env.process(customer(env, 'Customer %d' % i, bk))

    # Create more customers while the simulation is running
    i = 0
    while True:
        yield env.timeout(rnd.exponential(1 / arrival_rate))
        i += 1
        env.process(customer(env, 'Customer %d' % i, bk))

# Setup and start the simulation
print('Bank')

# Create an environment and start the setup process
env = simpy.Environment()
env.process(setup(env, NUM_DESKS, ARRIVAL_RATE, DEPARTURE_RATE))

# Execute!
env.run(until=SIM_TIME)

df=pd.DataFrame(events, columns=['time','name','event'])

fig, axs = plt.subplots(len(df['name'].drop_duplicates()),1,figsize=(15,10))
for ax,c in zip(axs.flatten(),df['name'].drop_duplicates()):
    df_c=df.loc[df['name'] == c]
    
    ax.step(df_c['time'],df_c['event'], label=c)
    ax.set_xlabel('Time')
    ax.set_ylabel('State')  
    ax.set_xlim(0, 45)
    ax.legend()

#performance
print(df)
df_w=df.loc[df['event'] == 'waiting']
print('average waiting time: %.2f minutes.' % df_w.mean())

plt.show()
# Out:
# Bank
# Customer 0 arrives at the Bank at 0.00.
# Customer 1 arrives at the Bank at 0.00.
# Customer 2 arrives at the Bank at 0.00.
# Customer 3 arrives at the Bank at 0.00.
# Customer 0 is being served at 0.00.
# Customer 1 arrives at the Bank at 0.03.
# The Bank agent is serving 81% of Customer 0's service request.
# Customer 0 leaves the Bank at 0.05.
# Customer 1 is being served at 0.05.
# Customer 2 arrives at the Bank at 0.07.
# Customer 3 arrives at the Bank at 0.07.
# Customer 4 arrives at the Bank at 0.10.
# Customer 5 arrives at the Bank at 0.18.
# The Bank agent is serving 96% of Customer 1's service request.
# Customer 1 leaves the Bank at 0.26.
# Customer 2 is being served at 0.26.
# The Bank agent is serving 82% of Customer 2's service request.
# Customer 2 leaves the Bank at 0.27.
# Customer 3 is being served at 0.27.
# Customer 6 arrives at the Bank at 0.29.
# Customer 7 arrives at the Bank at 0.30.
# The Bank agent is serving 80% of Customer 3's service request.
# Customer 3 leaves the Bank at 0.31.
# Customer 1 is being served at 0.31.
# Customer 8 arrives at the Bank at 0.33.
# Customer 9 arrives at the Bank at 0.47.
# The Bank agent is serving 97% of Customer 1's service request.
# Customer 1 leaves the Bank at 0.47.
# Customer 2 is being served at 0.47.
# The Bank agent is serving 82% of Customer 2's service request.
# Customer 2 leaves the Bank at 0.48.
# Customer 3 is being served at 0.48.
# Customer 10 arrives at the Bank at 0.50.
# The Bank agent is serving 76% of Customer 3's service request.
# Customer 3 leaves the Bank at 0.53.
# Customer 4 is being served at 0.53.
# The Bank agent is serving 85% of Customer 4's service request.
# Customer 4 leaves the Bank at 0.55.
# Customer 5 is being served at 0.55.
# The Bank agent is serving 91% of Customer 5's service request.
# Customer 5 leaves the Bank at 0.56.
# Customer 6 is being served at 0.56.
# The Bank agent is serving 80% of Customer 6's service request.
# Customer 6 leaves the Bank at 0.57.
# Customer 7 is being served at 0.57.
# Customer 11 arrives at the Bank at 0.57.
# The Bank agent is serving 93% of Customer 7's service request.
# Customer 7 leaves the Bank at 0.59.
# Customer 8 is being served at 0.59.
# Customer 12 arrives at the Bank at 0.61.
# Customer 13 arrives at the Bank at 0.65.
# Customer 14 arrives at the Bank at 0.66.
# Customer 15 arrives at the Bank at 0.68.
# The Bank agent is serving 82% of Customer 8's service request.
# Customer 8 leaves the Bank at 0.68.
# Customer 9 is being served at 0.68.
# The Bank agent is serving 81% of Customer 9's service request.
# Customer 9 leaves the Bank at 0.71.
# Customer 10 is being served at 0.71.
# Customer 16 arrives at the Bank at 0.83.
# Customer 17 arrives at the Bank at 0.97.
# Customer 18 arrives at the Bank at 0.97.
# Customer 19 arrives at the Bank at 1.02.
# Customer 20 arrives at the Bank at 1.10.
# Customer 21 arrives at the Bank at 1.11.
# The Bank agent is serving 76% of Customer 10's service request.
# Customer 10 leaves the Bank at 1.17.
# Customer 11 is being served at 1.17.
# Customer 22 arrives at the Bank at 1.19.
# Customer 23 arrives at the Bank at 1.25.
# Customer 24 arrives at the Bank at 1.34.
# Customer 25 arrives at the Bank at 1.35.
# Customer 26 arrives at the Bank at 1.36.
# Customer 27 arrives at the Bank at 1.37.
# Customer 28 arrives at the Bank at 1.40.
# Customer 29 arrives at the Bank at 1.40.
# Customer 30 arrives at the Bank at 1.41.
# The Bank agent is serving 86% of Customer 11's service request.
# Customer 11 leaves the Bank at 1.61.
# Customer 12 is being served at 1.61.
# The Bank agent is serving 80% of Customer 12's service request.
# Customer 12 leaves the Bank at 1.71.
# Customer 13 is being served at 1.71.
# Customer 31 arrives at the Bank at 1.73.
# Customer 32 arrives at the Bank at 1.79.
# Customer 33 arrives at the Bank at 1.80.
# The Bank agent is serving 83% of Customer 13's service request.
# Customer 13 leaves the Bank at 1.83.
# Customer 14 is being served at 1.83.
# The Bank agent is serving 75% of Customer 14's service request.
# Customer 14 leaves the Bank at 1.85.
# Customer 15 is being served at 1.85.
# Customer 34 arrives at the Bank at 1.96.
# Customer 35 arrives at the Bank at 2.28.
# The Bank agent is serving 93% of Customer 15's service request.
# Customer 15 leaves the Bank at 2.34.
# Customer 16 is being served at 2.34.
# Customer 36 arrives at the Bank at 2.34.
# Customer 37 arrives at the Bank at 2.44.
# The Bank agent is serving 97% of Customer 16's service request.
# Customer 16 leaves the Bank at 2.45.
# Customer 17 is being served at 2.45.
# Customer 38 arrives at the Bank at 2.55.
# Customer 39 arrives at the Bank at 2.61.
# Customer 40 arrives at the Bank at 2.62.
# The Bank agent is serving 90% of Customer 17's service request.
# Customer 17 leaves the Bank at 2.68.
# Customer 18 is being served at 2.68.
# Customer 41 arrives at the Bank at 2.97.
# The Bank agent is serving 84% of Customer 18's service request.
# Customer 18 leaves the Bank at 2.98.
# Customer 19 is being served at 2.98.
# Customer 42 arrives at the Bank at 2.99.
# Customer 43 arrives at the Bank at 3.11.
# Customer 44 arrives at the Bank at 3.15.
# Customer 45 arrives at the Bank at 3.26.
# Customer 46 arrives at the Bank at 3.27.
# Customer 47 arrives at the Bank at 3.28.
# The Bank agent is serving 96% of Customer 19's service request.
# Customer 19 leaves the Bank at 3.33.
# Customer 20 is being served at 3.33.
# Customer 48 arrives at the Bank at 3.35.
# Customer 49 arrives at the Bank at 3.37.
# The Bank agent is serving 97% of Customer 20's service request.
# Customer 20 leaves the Bank at 3.55.
# Customer 21 is being served at 3.55.
# Customer 50 arrives at the Bank at 3.62.
# Customer 51 arrives at the Bank at 3.63.
# The Bank agent is serving 77% of Customer 21's service request.
# Customer 21 leaves the Bank at 4.01.
# Customer 22 is being served at 4.01.
# The Bank agent is serving 80% of Customer 22's service request.
# Customer 22 leaves the Bank at 4.08.
# Customer 23 is being served at 4.08.
# The Bank agent is serving 89% of Customer 23's service request.
# Customer 23 leaves the Bank at 4.17.
# Customer 24 is being served at 4.17.
# The Bank agent is serving 90% of Customer 24's service request.
# Customer 24 leaves the Bank at 4.17.
# Customer 25 is being served at 4.17.
# Customer 52 arrives at the Bank at 4.28.
# The Bank agent is serving 96% of Customer 25's service request.
# Customer 25 leaves the Bank at 4.39.
# Customer 26 is being served at 4.39.
# Customer 53 arrives at the Bank at 4.46.
# The Bank agent is serving 86% of Customer 26's service request.
# Customer 26 leaves the Bank at 4.52.
# Customer 27 is being served at 4.52.
# Customer 54 arrives at the Bank at 4.83.
# The Bank agent is serving 96% of Customer 27's service request.
# Customer 27 leaves the Bank at 4.99.
# Customer 28 is being served at 4.99.
# Customer 55 arrives at the Bank at 5.01.
# Customer 56 arrives at the Bank at 5.02.
# Customer 57 arrives at the Bank at 5.06.
# Customer 58 arrives at the Bank at 5.10.
# Customer 59 arrives at the Bank at 5.18.
# Customer 60 arrives at the Bank at 5.21.
# Customer 61 arrives at the Bank at 5.41.
# The Bank agent is serving 84% of Customer 28's service request.
# Customer 28 leaves the Bank at 5.43.
# Customer 29 is being served at 5.43.
# The Bank agent is serving 94% of Customer 29's service request.
# Customer 29 leaves the Bank at 5.49.
# Customer 30 is being served at 5.49.
# The Bank agent is serving 92% of Customer 30's service request.
# Customer 30 leaves the Bank at 5.52.
# Customer 31 is being served at 5.52.
# The Bank agent is serving 91% of Customer 31's service request.
# Customer 31 leaves the Bank at 5.63.
# Customer 32 is being served at 5.63.
# Customer 62 arrives at the Bank at 5.73.
# Customer 63 arrives at the Bank at 5.75.
# Customer 64 arrives at the Bank at 5.76.
# Customer 65 arrives at the Bank at 5.79.
# Customer 66 arrives at the Bank at 5.87.
# Customer 67 arrives at the Bank at 5.96.
# Customer 68 arrives at the Bank at 5.96.
# The Bank agent is serving 93% of Customer 32's service request.
# Customer 32 leaves the Bank at 5.97.
# Customer 33 is being served at 5.97.
# Customer 69 arrives at the Bank at 6.19.
# Customer 70 arrives at the Bank at 6.19.
# The Bank agent is serving 95% of Customer 33's service request.
# Customer 33 leaves the Bank at 6.20.
# Customer 34 is being served at 6.20.
# Customer 71 arrives at the Bank at 6.22.
# Customer 72 arrives at the Bank at 6.24.
# The Bank agent is serving 79% of Customer 34's service request.
# Customer 34 leaves the Bank at 6.30.
# Customer 35 is being served at 6.30.
# Customer 73 arrives at the Bank at 6.33.
# Customer 74 arrives at the Bank at 6.34.
# The Bank agent is serving 90% of Customer 35's service request.
# Customer 35 leaves the Bank at 6.39.
# Customer 36 is being served at 6.39.
# Customer 75 arrives at the Bank at 6.50.
# The Bank agent is serving 75% of Customer 36's service request.
# Customer 36 leaves the Bank at 6.50.
# Customer 37 is being served at 6.50.
# Customer 76 arrives at the Bank at 6.55.
# Customer 77 arrives at the Bank at 6.59.
# The Bank agent is serving 85% of Customer 37's service request.
# Customer 37 leaves the Bank at 6.76.
# Customer 38 is being served at 6.76.
# Customer 78 arrives at the Bank at 6.86.
# Customer 79 arrives at the Bank at 6.87.
# Customer 80 arrives at the Bank at 6.92.
# Customer 81 arrives at the Bank at 6.92.
# Customer 82 arrives at the Bank at 7.08.
# The Bank agent is serving 77% of Customer 38's service request.
# Customer 38 leaves the Bank at 7.15.
# Customer 39 is being served at 7.15.
# The Bank agent is serving 78% of Customer 39's service request.
# Customer 39 leaves the Bank at 7.20.
# Customer 40 is being served at 7.20.
# Customer 83 arrives at the Bank at 7.28.
# Customer 84 arrives at the Bank at 7.34.
# Customer 85 arrives at the Bank at 7.34.
# The Bank agent is serving 81% of Customer 40's service request.
# Customer 40 leaves the Bank at 7.35.
# Customer 41 is being served at 7.35.
# Customer 86 arrives at the Bank at 7.35.
# The Bank agent is serving 95% of Customer 41's service request.
# Customer 41 leaves the Bank at 7.37.
# Customer 42 is being served at 7.37.
# Customer 87 arrives at the Bank at 7.54.
# Customer 88 arrives at the Bank at 7.68.
# Customer 89 arrives at the Bank at 7.68.
# Customer 90 arrives at the Bank at 7.96.
# Customer 91 arrives at the Bank at 8.01.
# The Bank agent is serving 88% of Customer 42's service request.
# Customer 42 leaves the Bank at 8.05.
# Customer 43 is being served at 8.05.
# Customer 92 arrives at the Bank at 8.08.
# The Bank agent is serving 87% of Customer 43's service request.
# Customer 43 leaves the Bank at 8.16.
# Customer 44 is being served at 8.16.
# The Bank agent is serving 84% of Customer 44's service request.
# Customer 44 leaves the Bank at 8.18.
# Customer 45 is being served at 8.18.
# Customer 93 arrives at the Bank at 8.24.
# Customer 94 arrives at the Bank at 8.29.
# The Bank agent is serving 96% of Customer 45's service request.
# Customer 45 leaves the Bank at 8.32.
# Customer 46 is being served at 8.32.
# Customer 95 arrives at the Bank at 8.35.
# Customer 96 arrives at the Bank at 8.50.
# The Bank agent is serving 84% of Customer 46's service request.
# Customer 46 leaves the Bank at 8.69.
# Customer 47 is being served at 8.69.
# Customer 97 arrives at the Bank at 8.80.
# The Bank agent is serving 87% of Customer 47's service request.
# Customer 47 leaves the Bank at 8.85.
# Customer 48 is being served at 8.85.
# The Bank agent is serving 90% of Customer 48's service request.
# Customer 48 leaves the Bank at 9.13.
# Customer 49 is being served at 9.13.
# Customer 98 arrives at the Bank at 9.14.
# Customer 99 arrives at the Bank at 9.23.
# Customer 100 arrives at the Bank at 9.23.
# Customer 101 arrives at the Bank at 9.25.
# Customer 102 arrives at the Bank at 9.26.
# Customer 103 arrives at the Bank at 9.45.
# Customer 104 arrives at the Bank at 9.51.
# The Bank agent is serving 90% of Customer 49's service request.
# Customer 49 leaves the Bank at 9.55.
# Customer 50 is being served at 9.55.
# The Bank agent is serving 93% of Customer 50's service request.
# Customer 50 leaves the Bank at 9.62.
# Customer 51 is being served at 9.62.
# The Bank agent is serving 77% of Customer 51's service request.
# Customer 51 leaves the Bank at 9.64.
# Customer 52 is being served at 9.64.
# The Bank agent is serving 95% of Customer 52's service request.
# Customer 52 leaves the Bank at 9.71.
# Customer 53 is being served at 9.71.
# The Bank agent is serving 92% of Customer 53's service request.
# Customer 53 leaves the Bank at 9.88.
# Customer 54 is being served at 9.88.
# Customer 105 arrives at the Bank at 9.97.
# Customer 106 arrives at the Bank at 9.98.
#          time          name       event
# 0    0.000000    Customer 0    arriving
# 1    0.000000    Customer 1    arriving
# 2    0.000000    Customer 2    arriving
# 3    0.000000    Customer 3    arriving
# 4    0.000000    Customer 0     waiting
# ..        ...           ...         ...
# 277  9.882532   Customer 53  in service
# 278  9.882532   Customer 53   departure
# 279  9.882532   Customer 54     waiting
# 280  9.965276  Customer 105    arriving
# 281  9.980313  Customer 106    arriving
#
# [282 rows x 3 columns]
# average waiting time: 4.46 minutes.
# C:\Users\habs\AppData\Local\Temp\ipykernel_14780\334428061.py:100: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('average waiting time: %.2f minutes.' % df_w.mean())

# %%
# Your code for M/M/3
import numpy.random as rnd
import simpy

RANDOM_SEED = 42
NUM_DESKS = 3      # Number of service desks in the Bank
ARRIVAL_RATE = 10  # Arrival rate of customers (per minute)
DEPARTURE_RATE = 5 # Departure rate of customers (per minute)
SIM_TIME = 1       # Simulation time in minutes

events = []

class Bank(object):
    """A Bank has a limited number of service desks (``NUM_DESKS``) to
    serve customers in parallel.

    Customers have to request one of the service desks. When they get one, they
    are served and wait for the agent to finish their request which 
    takes a random service time.

    """
    def __init__(self, env, num_desks, departure_rate):
        self.env = env
        self.desk = simpy.Resource(env, num_desks)
        self.departureRate = departure_rate

    def service(self, customer):
        """The service process. It takes a ``customer`` process and tries
        to serve it."""
        service_time = rnd.exponential(1 / self.departureRate)
        yield self.env.timeout(service_time)
        print("The Bank agent is serving %d%% of %s's service request." %
              (rnd.randint(75, 99), customer))
        events.append([env.now, customer, 'in service'])

def customer(env, name, bk):
    """
    The customer process (each customer has a ``name``) arrives at the Bank
    (``bk``) and requests a service desk.

    It then waits for the agent to finalize the request and
    leaves to never come back ...

    """
    print('%s arrives at the Bank at %.2f.' % (name, env.now))
    events.append([env.now, name, 'arriving'])
    with bk.desk.request() as request:
        # Waiting for the customer's turn to be served
        yield request
        events.append([env.now, name, 'waiting'])
        print('%s is being served at %.2f.' % (name, env.now))
        yield env.process(bk.service(name))
        events.append([env.now, name, 'departure'])
        print('%s leaves the Bank at %.2f.' % (name, env.now))

def setup(env, num_desks, arrival_rate, departure_rate):
    """
    Create a Bank, a number of initial customers, and keep creating customers
    with exponential inter-arrival times.
    """
    # Create the Bank
    bk = Bank(env, num_desks, departure_rate)

    # We assume that at the beginning the 4 customers are already in queue
    for i in range(4):
        env.process(customer(env, 'Customer %d' % i, bk))

    # Create more customers while the simulation is running
    i = 0
    while True:
        yield env.timeout(rnd.exponential(1 / arrival_rate))
        i += 1
        env.process(customer(env, 'Customer %d' % i, bk))

# Setup and start the simulation
print('Bank')

# Create an environment and start the setup process
env = simpy.Environment()
env.process(setup(env, NUM_DESKS, ARRIVAL_RATE, DEPARTURE_RATE))

# Execute!
env.run(until=SIM_TIME)

df=pd.DataFrame(events, columns=['time','name','event'])

fig, axs = plt.subplots(len(df['name'].drop_duplicates()),1,figsize=(15,10))
for ax,c in zip(axs.flatten(),df['name'].drop_duplicates()):
    df_c=df.loc[df['name'] == c]
    
    ax.step(df_c['time'],df_c['event'], label=c)
    ax.set_xlabel('Time')
    ax.set_ylabel('State')  
    ax.set_xlim(0, 45)
    ax.legend()

#performance
print(df)
df_w=df.loc[df['event'] == 'waiting']
print('average waiting time: %.2f minutes.' % df_w.mean())

plt.show()
# Out:
# Bank
# Customer 0 arrives at the Bank at 0.00.
# Customer 1 arrives at the Bank at 0.00.
# Customer 2 arrives at the Bank at 0.00.
# Customer 3 arrives at the Bank at 0.00.
# Customer 0 is being served at 0.00.
# Customer 1 is being served at 0.00.
# Customer 2 is being served at 0.00.
# Customer 1 arrives at the Bank at 0.00.
# Customer 2 arrives at the Bank at 0.01.
# Customer 3 arrives at the Bank at 0.02.
# Customer 4 arrives at the Bank at 0.02.
# Customer 5 arrives at the Bank at 0.04.
# Customer 6 arrives at the Bank at 0.15.
# Customer 7 arrives at the Bank at 0.21.
# The Bank agent is serving 85% of Customer 0's service request.
# Customer 0 leaves the Bank at 0.22.
# Customer 3 is being served at 0.22.
# The Bank agent is serving 98% of Customer 1's service request.
# Customer 1 leaves the Bank at 0.22.
# Customer 1 is being served at 0.22.
# The Bank agent is serving 91% of Customer 1's service request.
# Customer 1 leaves the Bank at 0.23.
# Customer 2 is being served at 0.23.
# The Bank agent is serving 76% of Customer 2's service request.
# Customer 2 leaves the Bank at 0.27.
# Customer 3 is being served at 0.27.
# The Bank agent is serving 85% of Customer 3's service request.
# Customer 3 leaves the Bank at 0.28.
# Customer 4 is being served at 0.28.
# The Bank agent is serving 77% of Customer 4's service request.
# Customer 4 leaves the Bank at 0.29.
# Customer 5 is being served at 0.29.
# The Bank agent is serving 80% of Customer 3's service request.
# Customer 3 leaves the Bank at 0.36.
# Customer 6 is being served at 0.36.
# The Bank agent is serving 87% of Customer 2's service request.
# Customer 2 leaves the Bank at 0.38.
# Customer 7 is being served at 0.38.
# Customer 8 arrives at the Bank at 0.42.
# The Bank agent is serving 80% of Customer 7's service request.
# Customer 7 leaves the Bank at 0.56.
# Customer 8 is being served at 0.56.
# The Bank agent is serving 79% of Customer 5's service request.
# Customer 5 leaves the Bank at 0.57.
# Customer 9 arrives at the Bank at 0.60.
# Customer 9 is being served at 0.60.
# The Bank agent is serving 76% of Customer 6's service request.
# Customer 6 leaves the Bank at 0.63.
# Customer 10 arrives at the Bank at 0.69.
# Customer 10 is being served at 0.69.
# The Bank agent is serving 83% of Customer 9's service request.
# Customer 9 leaves the Bank at 0.69.
# Customer 11 arrives at the Bank at 0.75.
# Customer 11 is being served at 0.75.
# The Bank agent is serving 75% of Customer 10's service request.
# Customer 10 leaves the Bank at 0.80.
# The Bank agent is serving 91% of Customer 11's service request.
# Customer 11 leaves the Bank at 0.84.
# Customer 12 arrives at the Bank at 0.96.
# Customer 12 is being served at 0.96.
# Customer 13 arrives at the Bank at 0.97.
# Customer 13 is being served at 0.97.
#         time         name      event
# 0   0.000000   Customer 0   arriving
# 1   0.000000   Customer 1   arriving
# 2   0.000000   Customer 2   arriving
# 3   0.000000   Customer 3   arriving
# 4   0.000000   Customer 0    waiting
# ..       ...          ...        ...
# 57  0.842408  Customer 11  departure
# 58  0.958306  Customer 12   arriving
# 59  0.958306  Customer 12    waiting
# 60  0.970220  Customer 13   arriving
# 61  0.970220  Customer 13    waiting
#
# [62 rows x 3 columns]
# average waiting time: 0.40 minutes.
# C:\Users\habs\AppData\Local\Temp\ipykernel_14780\2337946913.py:100: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('average waiting time: %.2f minutes.' % df_w.mean())
